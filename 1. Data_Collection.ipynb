# %% [markdown]
# #Importing Python Libaries

# %%
import numpy as np 
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Data Collection

# %%
df1  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Forest area (sq. km).csv', skiprows = [0, 1, 2, 3])
df1.head(2)
# Out:
#                   Country Name Country Code        Indicator Name  \
# 0                        Aruba          ABW  Forest area (sq. km)
# 1  Africa Eastern and Southern          AFE  Forest area (sq. km)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...        2013  \
# 0  AG.LND.FRST.K2   NaN   NaN   NaN   NaN   NaN   NaN  ...        4.20
# 1  AG.LND.FRST.K2   NaN   NaN   NaN   NaN   NaN   NaN  ...  4703021.74
#
#          2014       2015       2016       2017        2018       2019  \
# 0        4.20        4.2        4.2        4.2        4.20        4.2
# 1  4671832.12  4640642.5  4607876.1  4575901.2  4544314.78  4511676.2
#
#         2020  2021  Unnamed: 66
# 0        4.2   NaN          NaN
# 1  4479395.0   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df2  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Electric power consumption (kWh per capita).csv', skiprows = [0, 1, 2, 3])
df2.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                 Indicator Name     Indicator Code  1960  1961  \
# 0  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
# 1  Electric power consumption (kWh per capita)  EG.USE.ELEC.KH.PC   NaN   NaN
#
#    1962  1963  1964  1965  ...        2013        2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN  ...         NaN         NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN  ...  698.369914  686.728057   NaN   NaN   NaN
#
#    2018  2019  2020  2021  Unnamed: 66
# 0   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df3  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Electricity production from renewable sources.csv')
df3.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Electricity production from renewable sources,...  EG.ELC.RNWX.KH   NaN
# 1  Electricity production from renewable sources,...  EG.ELC.RNWX.KH   NaN
#
#    1961  1962  1963  1964  1965  ...          2013          2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  3.669000e+09  7.687000e+09
#
#            2015  2016  2017  2018  2019  2020  2021  Unnamed: 66
# 0           NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1  1.092600e+10   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df4  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Fossil fuel energy consumption (% of total).csv', skiprows = [0, 1, 2, 3])
df4.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                 Indicator Name     Indicator Code  1960  1961  \
# 0  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# 1  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
#
#    1962  1963  1964  1965  ...      2013       2014  2015  2016  2017  2018  \
# 0   NaN   NaN   NaN   NaN  ...       NaN        NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN  ...  46.89518  49.304292   NaN   NaN   NaN   NaN
#
#    2019  2020  2021  Unnamed: 66
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df5  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/GDP per capita (current US$).csv', skiprows = [0, 1, 2, 3])
df5.head(2)
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962       1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN        NaN         NaN
# 1  NY.GDP.PCAP.CD  153.494439  152.873313  162.413188  189.50617  168.816995
#
#          1965  ...          2013          2014          2015          2016  \
# 0         NaN  ...  26441.619936  26893.011506  28396.908423  28452.170615
# 1  187.396306  ...   1713.899299   1703.596298   1549.037940   1431.778723
#
#            2017          2018         2019         2020  2021  Unnamed: 66
# 0  29350.805019  30253.279358          NaN          NaN   NaN          NaN
# 1   1573.063386   1574.978648  1530.059177  1359.618224   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df6  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Renewable electricity output (% of total elect...csv', skiprows = [0, 1, 2, 3])
df6.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
# 1  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  14.912186  15.099280  14.856161   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  22.732604  24.966589  25.675879   NaN
#
#    2017  2018  2019  2020  2021  Unnamed: 66
# 0   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df7  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Total greenhouse gas emissions (kt of CO2 equivalent).csv', skiprows = [0, 1, 2, 3])
df7.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
# 1  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
#
#    1961  1962  1963  1964  1965  ...          2013          2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...  1.342550e+06  1.370950e+06
#
#            2015          2016          2017          2018          2019  2020  \
# 0           NaN           NaN           NaN           NaN           NaN   NaN
# 1  1.369670e+06  1.385480e+06  1.401180e+06  1.407690e+06  1.427180e+06   NaN
#
#    2021  Unnamed: 66
# 0   NaN          NaN
# 1   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df8  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Urban population (% of total population).csv', skiprows = [0, 1, 2, 3])
df8.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                              Indicator Name     Indicator Code       1960  \
# 0  Urban population (% of total population)  SP.URB.TOTL.IN.ZS  50.776000
# 1  Urban population (% of total population)  SP.URB.TOTL.IN.ZS  14.704688
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0  50.761000  50.746000  50.730000  50.715000  50.700000  ...  42.990000
# 1  14.944459  15.185608  15.444414  15.719076  16.001992  ...  33.507548
#
#         2014       2015       2016       2017      2018       2019       2020  \
# 0  43.041000  43.108000  43.192000  43.293000  43.41100  43.546000  43.697000
# 1  33.952424  34.405084  34.865101  35.332373  35.80777  36.291322  36.783306
#
#    2021  Unnamed: 66
# 0   NaN          NaN
# 1   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df9  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/ Foreign direct investment, net inflows.csv', skiprows = [0, 1, 2, 3])
df9.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
# 1  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD   NaN
#
#    1961  1962  1963  1964  1965  ...          2013          2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  2.263714e+08  2.506181e+08
# 1   NaN   NaN   NaN   NaN   NaN  ...  2.153424e+10  2.768142e+10
#
#            2015          2016          2017          2018          2019  \
# 0 -2.877586e+07  2.755127e+07  1.624636e+08  1.359212e+08 -7.522654e+07
# 1  2.877423e+10  1.684205e+10  9.955493e+09  1.444963e+10  1.468484e+10
#
#            2020  2021  Unnamed: 66
# 0  1.431161e+08   NaN          NaN
# 1  1.291341e+10   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df10  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/Methane emissions (kt of CO2 equivalent).csv', skiprows = [0, 1, 2, 3])
df10.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                              Indicator Name     Indicator Code  1960  1961  \
# 0  Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
# 1  Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
#
#    1962  1963  1964  1965  ...      2013      2014      2015      2016  \
# 0   NaN   NaN   NaN   NaN  ...       NaN       NaN       NaN       NaN
# 1   NaN   NaN   NaN   NaN  ...  538060.0  543720.0  554570.0  563050.0
#
#        2017      2018  2019  2020  2021  Unnamed: 66
# 0       NaN       NaN   NaN   NaN   NaN          NaN
# 1  564380.0  570040.0   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df11  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/CO2 emissions (metric tons per capita).csv', skiprows = [0, 1, 2, 3])
df11.head(2)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
#
#                            Indicator Name  Indicator Code  1960  1961  1962  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
#
#    1963  1964  1965  ...     2013      2014      2015      2016      2017  \
# 0   NaN   NaN   NaN  ...      NaN       NaN       NaN       NaN       NaN
# 1   NaN   NaN   NaN  ...  1.01882  1.028015  0.974941  0.958771  0.947872
#
#        2018  2019  2020  2021  Unnamed: 66
# 0       NaN   NaN   NaN   NaN          NaN
# 1  0.921768   NaN   NaN   NaN          NaN
#
# [2 rows x 67 columns]

# %%
df12  = pd.read_csv('/content/gdrive/MyDrive/UoH/Trimester 3/ALL DATASET (1)/co2/Others/CO2 emissions (kt).csv', skiprows = [0, 1, 2, 3])
df12.head(2)
# Out:
#                   Country Name Country Code      Indicator Name  \
# 0                        Aruba          ABW  CO2 emissions (kt)
# 1  Africa Eastern and Southern          AFE  CO2 emissions (kt)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...      2013  \
# 0  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1  EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...  573190.0
#
#        2014      2015      2016      2017      2018  2019  2020  2021  \
# 0       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN
# 1  594270.0  578990.0  584830.0  593740.0  592780.0   NaN   NaN   NaN
#
#    Unnamed: 66
# 0          NaN
# 1          NaN
#
# [2 rows x 67 columns]

# %% [markdown]
# # Dataset Harmonization

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True) #merging  dataset
df
# Out:
#                      Country Name Country Code        Indicator Name  \
# 0                           Aruba          ABW  Forest area (sq. km)
# 1     Africa Eastern and Southern          AFE  Forest area (sq. km)
# 2                     Afghanistan          AFG  Forest area (sq. km)
# 3      Africa Western and Central          AFW  Forest area (sq. km)
# 4                          Angola          AGO  Forest area (sq. km)
# ...                           ...          ...                   ...
# 3187                       Kosovo          XKX    CO2 emissions (kt)
# 3188                  Yemen, Rep.          YEM    CO2 emissions (kt)
# 3189                 South Africa          ZAF    CO2 emissions (kt)
# 3190                       Zambia          ZMB    CO2 emissions (kt)
# 3191                     Zimbabwe          ZWE    CO2 emissions (kt)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...        2013  \
# ...

# %%
df['Indicator Name'].unique() # to view indicator list in the dataset
# Out:
# array(['Forest area (sq. km)',
#        'Electric power consumption (kWh per capita)',
#        'Electricity production from renewable sources, excluding hydroelectric (kWh)',
#        'Fossil fuel energy consumption (% of total)',
#        'GDP per capita (current US$)',
#        'Renewable electricity output (% of total electricity output)',
#        'Total greenhouse gas emissions (kt of CO2 equivalent)',
#        'Urban population (% of total population)',
#        'Foreign direct investment, net inflows (BoP, current US$)',
#        'Methane emissions (kt of CO2 equivalent)',
#        'CO2 emissions (metric tons per capita)', 'CO2 emissions (kt)'],
#       dtype=object)

# %%
# define shorter names corresponding to most relevant variables in a dictionary
chosen_vars = {'Forest area (sq. km)': 'Forest Area',
               'Electric power consumption (kWh per capita)': 'Electric Power Consm',
               'Electricity production from renewable sources, excluding hydroelectric (kWh)': 'Electric Prod From Ren',
               'Fossil fuel energy consumption (% of total)': 'Foss Fuel Energy Consm',
               'GDP per capita (current US$)' : 'GDP Per Capita',
               'Renewable electricity output (% of total electricity output)': 'Renewable Electric Output',
               'Total greenhouse gas emissions (kt of CO2 equivalent)': 'Total Greenhouse Gas Emissions',
               'Urban population (% of total population)': 'Urban Population',
               'Foreign direct investment, net inflows (BoP, current US$)' : 'Foreign Direct Investment',
               'Methane emissions (kt of CO2 equivalent)': 'Methane Emissions',
               'CO2 emissions (metric tons per capita)': 'CO2 Emissions Per Capita', 
               'CO2 emissions (kt)': 'CO2 Emissions',
                }
# rename all variables in the column "Series name" with comprehensible shorter versions
df['Indicator Name'] = df['Indicator Name'].replace(to_replace=chosen_vars)

# %%
df = df.drop(['Country Code', 'Indicator Code'], axis = 1) #droppping country code and indicator code as they are not useful for the analysis

# %%
df
# Out:
#                      Country Name Indicator Name  1960  1961  1962  1963  \
# 0                           Aruba    Forest Area   NaN   NaN   NaN   NaN
# 1     Africa Eastern and Southern    Forest Area   NaN   NaN   NaN   NaN
# 2                     Afghanistan    Forest Area   NaN   NaN   NaN   NaN
# 3      Africa Western and Central    Forest Area   NaN   NaN   NaN   NaN
# 4                          Angola    Forest Area   NaN   NaN   NaN   NaN
# ...                           ...            ...   ...   ...   ...   ...
# 3187                       Kosovo  CO2 Emissions   NaN   NaN   NaN   NaN
# 3188                  Yemen, Rep.  CO2 Emissions   NaN   NaN   NaN   NaN
# 3189                 South Africa  CO2 Emissions   NaN   NaN   NaN   NaN
# 3190                       Zambia  CO2 Emissions   NaN   NaN   NaN   NaN
# 3191                     Zimbabwe  CO2 Emissions   NaN   NaN   NaN   NaN
#
#       1964  1965  1966  1967  ...        2013        2014       2015  \
# ...

# %%
# save the short feature names into a list of strings
chosen_cols = list(chosen_vars.values())

# define an empty list, where sub-dataframes for each feature will be saved
frame_list = []

# iterate over all chosen features
for variable in chosen_cols:
    
    # pick only rows corresponding to the current feature
    frame = df[df['Indicator Name'] == variable]
    
    # melt all the values for all years into one column and rename the columns correspondingly
    frame = frame.melt(id_vars=['Country Name', 'Indicator Name']).rename(columns={'Country Name': 'country', 'variable': 'year', 'value': variable}).drop(['Indicator Name'], axis='columns')
    
    # add the melted dataframe for the current feature into the list
    frame_list.append(frame)


# merge all sub-frames into a single dataframe, making an outer binding on the key columns 'country','year'
from functools import reduce
all_vars = reduce(lambda left, right: pd.merge(left, right, on=['country','year'], how='outer'), frame_list)

# %%
all_vars.shape # to  view the shape of the dataset
# Out:
# (16821, 14)

# %%
all_vars #displaying the dataset
# Out:
#                            country         year  Forest Area  \
# 0                            Aruba         1960          NaN
# 1      Africa Eastern and Southern         1960          NaN
# 2                      Afghanistan         1960          NaN
# 3       Africa Western and Central         1960          NaN
# 4                           Angola         1960          NaN
# ...                            ...          ...          ...
# 16816                      Turkiye         2018          NaN
# 16817                      Turkiye         2019          NaN
# 16818                      Turkiye         2020          NaN
# 16819                      Turkiye         2021          NaN
# 16820                      Turkiye  Unnamed: 66          NaN
#
#        Electric Power Consm  Electric Prod From Ren  Foss Fuel Energy Consm  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# ...

# %%
all_vars[all_vars['year'] == '2021'] # to view the dats for the year 2021
# Out:
#                            country  year  Forest Area  Electric Power Consm  \
# 16226                        Aruba  2021          NaN                   NaN
# 16227  Africa Eastern and Southern  2021          NaN                   NaN
# 16228                  Afghanistan  2021          NaN                   NaN
# 16229   Africa Western and Central  2021          NaN                   NaN
# 16230                       Angola  2021          NaN                   NaN
# ...                            ...   ...          ...                   ...
# 16488                  Yemen, Rep.  2021          NaN                   NaN
# 16489                 South Africa  2021          NaN                   NaN
# 16490                       Zambia  2021          NaN                   NaN
# 16491                     Zimbabwe  2021          NaN                   NaN
# 16819                      Turkiye  2021          NaN                   NaN
#
# ...

# %% [markdown]
# #Data Overview

# %%
print('Shape of data:') # to  view the shape of the dataset
all_vars.shape
# Out:
# Shape of data:
# (16821, 14)

# %%
print('Data preview:') # to see dataset haeder
all_vars.head()
# Out:
# Data preview:
#                        country  year  Forest Area  Electric Power Consm  \
# 0                        Aruba  1960          NaN                   NaN
# 1  Africa Eastern and Southern  1960          NaN                   NaN
# 2                  Afghanistan  1960          NaN                   NaN
# 3   Africa Western and Central  1960          NaN                   NaN
# 4                       Angola  1960          NaN                   NaN
#
#    Electric Prod From Ren  Foss Fuel Energy Consm  GDP Per Capita  \
# 0                     NaN                     NaN             NaN
# 1                     NaN                     NaN      153.494439
# 2                     NaN                     NaN       59.773234
# 3                     NaN                     NaN      107.932233
# 4                     NaN                     NaN             NaN
#
#    Renewable Electric Output  Total Greenhouse Gas Emissions  \
# ...

# %%
#column description
# Print the columns as list
all_vars.columns
# Out:
# Index(['country', 'year', 'Forest Area', 'Electric Power Consm',
#        'Electric Prod From Ren', 'Foss Fuel Energy Consm', 'GDP Per Capita',
#        'Renewable Electric Output', 'Total Greenhouse Gas Emissions',
#        'Urban Population', 'Foreign Direct Investment', 'Methane Emissions',
#        'CO2 Emissions Per Capita', 'CO2 Emissions'],
#       dtype='object')

# %%
print('Data type per column:')  #to view the datatype
all_vars.dtypes
# Out:
# Data type per column:
# country                            object
# year                               object
# Forest Area                       float64
# Electric Power Consm              float64
# Electric Prod From Ren            float64
# Foss Fuel Energy Consm            float64
# GDP Per Capita                    float64
# Renewable Electric Output         float64
# Total Greenhouse Gas Emissions    float64
# Urban Population                  float64
# Foreign Direct Investment         float64
# Methane Emissions                 float64
# CO2 Emissions Per Capita          float64
# CO2 Emissions                     float64
# dtype: object

# %%
print('Statistical summary:') #To get the descriptive statistics of the dataset
all_vars.describe()
# Out:
# Statistical summary:
#         Forest Area  Electric Power Consm  Electric Prod From Ren  \
# count  8.034000e+03           7787.000000            8.360000e+03
# mean   1.646711e+06           2890.118085            1.251493e+10
# std    4.942504e+06           4108.988549            6.714642e+10
# min    0.000000e+00              5.757767            0.000000e+00
# 25%    3.453675e+03            380.790967            0.000000e+00
# 50%    3.621631e+04           1340.446310            5.200000e+07
# 75%    2.808275e+05           3894.660585            1.497000e+09
# max    4.128269e+07          54799.174708            1.644540e+12
#
#        Foss Fuel Energy Consm  GDP Per Capita  Renewable Electric Output  \
# count             8175.000000    12851.000000                6894.000000
# mean                66.902852     7958.522193                  28.265195
# std                 29.008120    16053.126704                  31.419639
# ...

# %%
print('The missing values in the original dataset per column:') #To view the number of missing values for each column
all_vars.isna().sum()
# Out:
# The missing values in the original dataset per column:
# country                              0
# year                                 0
# Forest Area                       8787
# Electric Power Consm              9034
# Electric Prod From Ren            8461
# Foss Fuel Energy Consm            8646
# GDP Per Capita                    3970
# Renewable Electric Output         9927
# Total Greenhouse Gas Emissions    9652
# Urban Population                   787
# Foreign Direct Investment         5602
# Methane Emissions                 9893
# CO2 Emissions Per Capita          9894
# CO2 Emissions                     9891
# dtype: int64

# %%
#To plot the co2 emmision trend over the years
plt.figure(figsize = (15,8))
sns.lineplot(x="year", y="CO2 Emissions", data=all_vars)
plt.title('CO2 Emission Trends')
plt.show()

# %%
#To plot the co2 emmision per capita trend over the years
plt.figure(figsize = (15,8))
sns.lineplot(x="year", y="CO2 Emissions Per Capita", data=all_vars)
plt.title('CO2 Emissions Per Capita Trends')
plt.show()

# %%
all_vars['year'].unique() #To identify the unique values in the year column
# Out:
# array(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', 'Unnamed: 66'],
#       dtype=object)

# %%
from google.colab import files #To import library for saving and downloading dataset

# %%
all_vars.to_csv('data.csv', index=False)

# %%
files.download('data.csv') #file download with specific name
